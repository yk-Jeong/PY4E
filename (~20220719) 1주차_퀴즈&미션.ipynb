# %% [markdown]
# <a href="https://colab.research.google.com/github/yk-Jeong/PY4E/blob/main/(~20220719)%201%EC%A3%BC%EC%B0%A8_%ED%80%B4%EC%A6%88%26%EB%AF%B8%EC%85%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 파이썬의 예약어가 아닌 것은?

# %%
print(print)
# Out:
# <built-in function print>

# %% [markdown]
# while문의 활용

# %%
x = 10 
while x > 5:
  print(x)
  x = x-1

if x < 5:
  print("x is smaller than 5")
# Out:
# 10
# 9
# 8
# 7
# 6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Quiz 2.

# %%
result = 2 + 4 / 2 * 4
print(result)
# Out:
# 10.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)
